# %%
import pandas as pd

import numpy as np

df = pd.read_csv("D:/B5/Mall_Customers_TH.csv")
#show thông tin cơ bản
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
import seaborn as sns

sns.scatterplot(data=df, x='Genre', y='Annual Income (k$)')
# Out:
# <Axes: xlabel='Genre', ylabel='Annual Income (k$)'>

# %%
import sklearn.preprocessing as pp
import matplotlib.pyplot as plt
minmax = pp.MinMaxScaler(feature_range=(0,1))
data_minmax = minmax.fit_transform(df[['Age','Annual Income (k$)','Spending Score (1-100)']])
print(data_minmax)
standard = pp.StandardScaler()
data_standard = standard.fit_transform(df[['Age','Annual Income (k$)','Spending Score (1-100)']])
print(data_standard)
# Out:
# [[0.01923077 0.         0.3877551 ]
#  [0.05769231 0.         0.81632653]
#  [0.03846154 0.00819672 0.05102041]
#  [0.09615385 0.00819672 0.7755102 ]
#  [0.25       0.01639344 0.39795918]
#  [0.07692308 0.01639344 0.76530612]
#  [0.32692308 0.02459016 0.05102041]
#  [0.09615385 0.02459016 0.94897959]
#  [0.88461538 0.03278689 0.02040816]
#  [0.23076923 0.03278689 0.7244898 ]
#  [0.94230769 0.03278689 0.13265306]
#  [0.32692308 0.03278689 1.        ]
#  [0.76923077 0.04098361 0.14285714]
#  [0.11538462 0.04098361 0.7755102 ]
#  [0.36538462 0.04098361 0.12244898]
#  [0.07692308 0.04098361 0.79591837]
#  [0.32692308 0.04918033 0.34693878]
#  [0.03846154 0.04918033 0.66326531]
#  [0.65384615 0.06557377 0.28571429]
#  [0.32692308 0.06557377 0.98979592]
#  [0.32692308 0.07377049 0.34693878]
#  [0.13461538 0.07377049 0.73469388]
#  [0.53846154 0.08196721 0.04081633]
#  [0.25       0.08196721 0.73469388]
#  [0.69230769 0.10655738 0.13265306]
#  [0.21153846 0.10655738 0.82653061]
# ...

# %%
import sklearn.preprocessing as pp
from sklearn.cluster import KMeans
scaler = pp.MinMaxScaler()
df_scaled = scaler.fit_transform(df)

inertia = []
silhouette_scores = []

k_values = range(2, 11)
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)
    silhouette_scores.append(pp.silhouette_score(df_scaled, kmeans.labels_))

# Vẽ Elbow Method
plt.plot(k_values, inertia, marker='o')
plt.xlabel('Số cụm (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

# Vẽ Silhouette Score
plt.plot(k_values, silhouette_scores, marker='o', color='green')
plt.xlabel('Số cụm (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score cho từng k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21128\2300493892.py in ?()
#       1 import sklearn.preprocessing as pp
#       2 from sklearn.cluster import KMeans
#       3 scaler = pp.MinMaxScaler()
# ----> 4 df_scaled = scaler.fit_transform(df)
#       5
#       6 inertia = []
#       7 silhouette_scores = []
#
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# ...
